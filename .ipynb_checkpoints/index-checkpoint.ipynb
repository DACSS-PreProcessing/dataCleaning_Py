# %% [markdown]
# <center><img src="https://github.com/DACSS-PreProcessing/Week_1_main/blob/main/pics/LogoSimple.png?raw=true" width="700"></center>
#
# <a target="_blank" href="https://colab.research.google.com/github/DACSS-PreProcessing/dataCleaning_Py/blob/main/index.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
# # Data Cleaning in Python

# %% [markdown]
# <a id='home'></a>
#
# In the session we will:
#
# 1. Collect data as a dataframe
#
# 2. Clean data:
#     * Fix column names
#     * Fix data contents

# %% [markdown]
# ## 1. Collect data tables
#
#
# ### Read a File
#
# I have the data on the **Human Development Index** in a  folder in a GitHub repo, which I downloaded from this [link](https://hdr.undp.org/data-center/documentation-and-downloads) (_Table 1_).

# %%
# Location of data file
linkFile="https://github.com/DACSS-PreProcessing/dataCleaning/raw/main/data/HDI_Table.xlsx"

# %% [markdown]
# Reading in a table from a file using pandas, since it is an Excel file, I need that the package **openpyxl** is previously installed:

# %%
# available in my computer?
# !pip show openpyxl
# Out:
# Name: openpyxl
# Version: 3.1.2
# Summary: A Python library to read/write Excel 2010 xlsx/xlsm files
# Home-page: https://openpyxl.readthedocs.io
# Author: See AUTHORS
# Author-email: charlie.clark@clark-consulting.eu
# License: MIT
# Location: /Users/JoseManuel/opt/anaconda3/envs/workshopRPy/lib/python3.12/site-packages
# Requires: et-xmlfile
# Required-by:

# %% [markdown]
# If not available, please go to Anaconda and install it. Once installed, or if available, continue:

# %%
import pandas as pd

hdiFile=pd.read_excel(linkFile)

# %% [markdown]
# Take a look:

# %%
hdiFile
# Out:
#          Back Table 1. Human Development Index and its components   \
# 0         NaN                                                NaN
# 1         NaN                                                NaN
# 2         NaN                                                NaN
# 3         NaN                                                NaN
# 4    HDI rank                                            Country
# ..        ...                                                ...
# 271       NaN                          Column 2: UNDESA (2022a).
# 272       NaN  Column 3: CEDLAS and World Bank (2022), ICF Ma...
# 273       NaN  Column 4: Barro and Lee (2018), ICF Macro Demo...
# 274       NaN  Column 5: IMF (2022), UNDESA (2022b), United N...
# 275       NaN  Column 6: Calculated based on data in columns ...
#
#                          Unnamed: 2  Unnamed: 3                Unnamed: 4  \
# 0                               NaN         NaN                       NaN
# 1                               NaN         NaN                      SDG3
# 2                               NaN         NaN                       NaN
# 3    Human Development Index (HDI)          NaN  Life expectancy at birth
# 4                             Value         NaN                   (years)
# ..                              ...         ...                       ...
# 271                             NaN         NaN                       NaN
# 272                             NaN         NaN                       NaN
# 273                             NaN         NaN                       NaN
# 274                             NaN         NaN                       NaN
# 275                             NaN         NaN                       NaN
#
#     Unnamed: 5                   Unnamed: 6 Unnamed: 7  \
# 0          NaN                          NaN        NaN
# 1          NaN                       SDG4.3        NaN
# 2          NaN                          NaN        NaN
# 3          NaN  Expected years of schooling        NaN
# 4          NaN                      (years)        NaN
# ..         ...                          ...        ...
# 271        NaN                          NaN        NaN
# 272        NaN                          NaN        NaN
# 273        NaN                          NaN        NaN
# 274        NaN                          NaN        NaN
# 275        NaN                          NaN        NaN
#
#                   Unnamed: 8 Unnamed: 9  \
# 0                        NaN        NaN
# 1                     SDG4.4        NaN
# 2                        NaN        NaN
# 3    Mean years of schooling        NaN
# 4                    (years)        NaN
# ..                       ...        ...
# 271                      NaN        NaN
# 272                      NaN        NaN
# 273                      NaN        NaN
# 274                      NaN        NaN
# 275                      NaN        NaN
#
#                                 Unnamed: 10 Unnamed: 11  \
# 0                                       NaN         NaN
# 1                                    SDG8.5         NaN
# 2                                       NaN         NaN
# 3    Gross national income (GNI) per capita         NaN
# 4                              (2017 PPP $)         NaN
# ..                                      ...         ...
# 271                                     NaN         NaN
# 272                                     NaN         NaN
# 273                                     NaN         NaN
# 274                                     NaN         NaN
# 275                                     NaN         NaN
#
#                             Unnamed: 12 Unnamed: 13 Unnamed: 14
# 0                                   NaN         NaN         NaN
# 1                                   NaN         NaN         NaN
# 2                                   NaN         NaN         NaN
# 3    GNI per capita rank minus HDI rank         NaN    HDI rank
# 4                                   NaN         NaN         NaN
# ..                                  ...         ...         ...
# 271                                 NaN         NaN         NaN
# 272                                 NaN         NaN         NaN
# 273                                 NaN         NaN         NaN
# 274                                 NaN         NaN         NaN
# 275                                 NaN         NaN         NaN
#
# [276 rows x 15 columns]

# %% [markdown]
# ## 2. Cleaning Process
#
#
# ### Fix column names
#
# #### Recover column names
#
# Notice that we do not have the right column names. So we need to save them before we go on:

# %%
hdiFile.iloc[[3,4],:]
# Out:
#        Back Table 1. Human Development Index and its components   \
# 3       NaN                                                NaN
# 4  HDI rank                                            Country
#
#                        Unnamed: 2  Unnamed: 3                Unnamed: 4  \
# 3  Human Development Index (HDI)          NaN  Life expectancy at birth
# 4                           Value         NaN                   (years)
#
#   Unnamed: 5                   Unnamed: 6 Unnamed: 7               Unnamed: 8  \
# 3        NaN  Expected years of schooling        NaN  Mean years of schooling
# 4        NaN                      (years)        NaN                  (years)
#
#   Unnamed: 9                             Unnamed: 10 Unnamed: 11  \
# 3        NaN  Gross national income (GNI) per capita         NaN
# 4        NaN                            (2017 PPP $)         NaN
#
#                           Unnamed: 12 Unnamed: 13 Unnamed: 14
# 3  GNI per capita rank minus HDI rank         NaN    HDI rank
# 4                                 NaN         NaN         NaN

# %% [markdown]
# As you see, the column names are in different positions:

# %%
# here
hdiFile.iloc[3,2:]
# Out:
# Unnamed: 2             Human Development Index (HDI)
# Unnamed: 3                                        NaN
# Unnamed: 4                   Life expectancy at birth
# Unnamed: 5                                        NaN
# Unnamed: 6                Expected years of schooling
# Unnamed: 7                                        NaN
# Unnamed: 8                    Mean years of schooling
# Unnamed: 9                                        NaN
# Unnamed: 10    Gross national income (GNI) per capita
# Unnamed: 11                                       NaN
# Unnamed: 12        GNI per capita rank minus HDI rank
# Unnamed: 13                                       NaN
# Unnamed: 14                                  HDI rank
# Name: 3, dtype: object

# %%
# and here
hdiFile.iloc[4,:2]
# Out:
# Back                                                    HDI rank
# Table 1. Human Development Index and its components      Country
# Name: 4, dtype: object

# %% [markdown]
# It is easier if we have lists, so we can concatenate:

# %%
# save column names turned to lists

RealHeaders=hdiFile.iloc[4,:2].to_list()+hdiFile.iloc[3,2:].to_list()

# these are:
RealHeaders
# Out:
# ['HDI rank',
#  'Country',
#  'Human Development Index (HDI) ',
#  nan,
#  'Life expectancy at birth',
#  nan,
#  'Expected years of schooling',
#  nan,
#  'Mean years of schooling',
#  nan,
#  'Gross national income (GNI) per capita',
#  nan,
#  'GNI per capita rank minus HDI rank',
#  nan,
#  'HDI rank']

# %% [markdown]
# Let's put the rown in the right place:

# %%
# rename all the columns
hdiFile.columns=RealHeaders

# newDF
better_1=hdiFile.copy()

# see head
better_1.head()
# Out:
#    HDI rank  Country  Human Development Index (HDI)  NaN  \
# 0       NaN      NaN                             NaN NaN
# 1       NaN      NaN                             NaN NaN
# 2       NaN      NaN                             NaN NaN
# 3       NaN      NaN  Human Development Index (HDI)  NaN
# 4  HDI rank  Country                           Value NaN
#
#    Life expectancy at birth  NaN  Expected years of schooling  NaN  \
# 0                       NaN  NaN                          NaN  NaN
# 1                      SDG3  NaN                       SDG4.3  NaN
# 2                       NaN  NaN                          NaN  NaN
# 3  Life expectancy at birth  NaN  Expected years of schooling  NaN
# 4                   (years)  NaN                      (years)  NaN
#
#    Mean years of schooling  NaN  Gross national income (GNI) per capita  NaN  \
# 0                      NaN  NaN                                     NaN  NaN
# 1                   SDG4.4  NaN                                  SDG8.5  NaN
# 2                      NaN  NaN                                     NaN  NaN
# 3  Mean years of schooling  NaN  Gross national income (GNI) per capita  NaN
# 4                  (years)  NaN                            (2017 PPP $)  NaN
#
#    GNI per capita rank minus HDI rank  NaN  HDI rank
# 0                                 NaN  NaN       NaN
# 1                                 NaN  NaN       NaN
# 2                                 NaN  NaN       NaN
# 3  GNI per capita rank minus HDI rank  NaN  HDI rank
# 4                                 NaN  NaN       NaN

# %% [markdown]
# #### Subset to drop unneeded columns
#
#
# Notice the repeated column names (HDI rank) and _NaN_. Notice also that we do not need the three columns next to it. Let's rewrite the original:

# %%
# without the last four
better_2=better_1.iloc[:,:-4]

# %% [markdown]
# We still have column names with missing values:

# %%
better_2.columns
# Out:
# Index([                              'HDI rank',
#                                       'Country',
#                'Human Development Index (HDI) ',
#                                             nan,
#                      'Life expectancy at birth',
#                                             nan,
#                   'Expected years of schooling',
#                                             nan,
#                       'Mean years of schooling',
#                                             nan,
#        'Gross national income (GNI) per capita'],
#       dtype='object')

# %% [markdown]
# ...let's get rid of those missing values in the column names:

# %%
# columns names without missings values
BetterHeaders=better_2.columns.dropna()
BetterHeaders
# Out:
# Index(['HDI rank', 'Country', 'Human Development Index (HDI) ',
#        'Life expectancy at birth', 'Expected years of schooling',
#        'Mean years of schooling', 'Gross national income (GNI) per capita'],
#       dtype='object')

# %% [markdown]
# Let's proceed:

# %%
#subsetting again to keep the good headers
better_2=better_2.loc[:,BetterHeaders]

#see
better_2.head(10)
# Out:
#    HDI rank                      Country  Human Development Index (HDI)   \
# 0       NaN                          NaN                             NaN
# 1       NaN                          NaN                             NaN
# 2       NaN                          NaN                             NaN
# 3       NaN                          NaN  Human Development Index (HDI)
# 4  HDI rank                      Country                           Value
# 5       NaN                          NaN                            2021
# 6       NaN  VERY HIGH HUMAN DEVELOPMENT                             NaN
# 7         1                  Switzerland                           0.962
# 8         2                       Norway                           0.961
# 9         3                      Iceland                           0.959
#
#    Life expectancy at birth  Expected years of schooling  \
# 0                       NaN                          NaN
# 1                      SDG3                       SDG4.3
# 2                       NaN                          NaN
# 3  Life expectancy at birth  Expected years of schooling
# 4                   (years)                      (years)
# 5                      2021                         2021
# 6                       NaN                          NaN
# 7                   83.9872                    16.500299
# 8                   83.2339                      18.1852
# 9                   82.6782                    19.163059
#
#    Mean years of schooling  Gross national income (GNI) per capita
# 0                      NaN                                     NaN
# 1                   SDG4.4                                  SDG8.5
# 2                      NaN                                     NaN
# 3  Mean years of schooling  Gross national income (GNI) per capita
# 4                  (years)                            (2017 PPP $)
# 5                     2021                                    2021
# 6                      NaN                                     NaN
# 7                 13.85966                             66933.00454
# 8                 13.00363                             64660.10622
# 9                 13.76717                             55782.04981

# %% [markdown]
# It is time to offer a better set of column names.

# %% [markdown]
# #### Clean column names
#
# The current situation:

# %%
better_3=better_2.copy()
better_3.columns.to_list() # always use to_list()
# Out:
# ['HDI rank',
#  'Country',
#  'Human Development Index (HDI) ',
#  'Life expectancy at birth',
#  'Expected years of schooling',
#  'Mean years of schooling',
#  'Gross national income (GNI) per capita']

# %% [markdown]
# Notice above that the columns:
# * Have acronyms in parenthesis.
# * Have spaces between words.
#
# Let's get rid of the acronyms in parentheses:

# %%
# bye anything between parentheses (then strip and title case)

pattern1=r'\(.+\)'
better_3.columns=better_3.columns.str.replace(pattern1,repl="", regex=True).str.strip().str.title()
better_3.columns
# Out:
# Index(['Hdi Rank', 'Country', 'Human Development Index',
#        'Life Expectancy At Birth', 'Expected Years Of Schooling',
#        'Mean Years Of Schooling', 'Gross National Income  Per Capita'],
#       dtype='object')

# %% [markdown]
# **Option 1**: Underscores instead of _blank spaces_.

# %%
# spaces replaced
pattern2=r'\s+'
better_3.columns.str.replace(pattern2,repl='_',regex=True)
# Out:
# Index(['Hdi_Rank', 'Country', 'Human_Development_Index',
#        'Life_Expectancy_At_Birth', 'Expected_Years_Of_Schooling',
#        'Mean_Years_Of_Schooling', 'Gross_National_Income_Per_Capita'],
#       dtype='object')

# %% [markdown]
# **Option 2**: Shorthening using Camel case

# %%
# title case, the bye spaces
better_3.columns.str.replace(" ",'',regex=False)
# Out:
# Index(['HdiRank', 'Country', 'HumanDevelopmentIndex', 'LifeExpectancyAtBirth',
#        'ExpectedYearsOfSchooling', 'MeanYearsOfSchooling',
#        'GrossNationalIncomePerCapita'],
#       dtype='object')

# %% [markdown]
# **Option 3**: Shorthening using Acronyms
#
# This option requires a good data dictionary in your README. Notice we will do this only for the _variables_:

# %%
# concatenating
acronyms=[''.join([word[0] for word in name.split()]) for name in better_3.columns[2:]]
acronyms
# Out:
# ['HDI', 'LEAB', 'EYOS', 'MYOS', 'GNIPC']

# %%
changesToNames={old:new for old,new in zip(better_3.columns[2:],acronyms)}
changesToNames # dictionary
# Out:
# {'Human Development Index': 'HDI',
#  'Life Expectancy At Birth': 'LEAB',
#  'Expected Years Of Schooling': 'EYOS',
#  'Mean Years Of Schooling': 'MYOS',
#  'Gross National Income  Per Capita': 'GNIPC'}

# %%
better_3.rename(columns=changesToNames,inplace=True)
better_3.columns
# Out:
# Index(['Hdi Rank', 'Country', 'HDI', 'LEAB', 'EYOS', 'MYOS', 'GNIPC'], dtype='object')

# %% [markdown]
# We are keeping the last one:

# %%
better_3.head(10)
# Out:
#    HDI rank                      Country                             HDI  \
# 0       NaN                          NaN                             NaN
# 1       NaN                          NaN                             NaN
# 2       NaN                          NaN                             NaN
# 3       NaN                          NaN  Human Development Index (HDI)
# 4  HDI rank                      Country                           Value
# 5       NaN                          NaN                            2021
# 6       NaN  VERY HIGH HUMAN DEVELOPMENT                             NaN
# 7         1                  Switzerland                           0.962
# 8         2                       Norway                           0.961
# 9         3                      Iceland                           0.959
#
#                        LEAB                         EYOS  \
# 0                       NaN                          NaN
# 1                      SDG3                       SDG4.3
# 2                       NaN                          NaN
# 3  Life expectancy at birth  Expected years of schooling
# 4                   (years)                      (years)
# 5                      2021                         2021
# 6                       NaN                          NaN
# 7                   83.9872                    16.500299
# 8                   83.2339                      18.1852
# 9                   82.6782                    19.163059
#
#                       MYOS                                   GNIPC
# 0                      NaN                                     NaN
# 1                   SDG4.4                                  SDG8.5
# 2                      NaN                                     NaN
# 3  Mean years of schooling  Gross national income (GNI) per capita
# 4                  (years)                            (2017 PPP $)
# 5                     2021                                    2021
# 6                      NaN                                     NaN
# 7                 13.85966                             66933.00454
# 8                 13.00363                             64660.10622
# 9                 13.76717                             55782.04981

# %% [markdown]
# ______
#
#
# ### Fix Data contents
#
# After becoming familar with the data, we focus on data contents.
#
# #### Cleaning based on cells with missing values:
#
# See all rows with at least one missing value:

# %%
# next DF
better_4=better_3.copy()
better_4[better_4.isna().any(axis=1)]
# Out:
#     Hdi Rank                                            Country  \
# 0        NaN                                                NaN
# 1        NaN                                                NaN
# 2        NaN                                                NaN
# 3        NaN                                                NaN
# 5        NaN                                                NaN
# ..       ...                                                ...
# 271      NaN                          Column 2: UNDESA (2022a).
# 272      NaN  Column 3: CEDLAS and World Bank (2022), ICF Ma...
# 273      NaN  Column 4: Barro and Lee (2018), ICF Macro Demo...
# 274      NaN  Column 5: IMF (2022), UNDESA (2022b), United N...
# 275      NaN  Column 6: Calculated based on data in columns ...
#
#                                 HDI                      LEAB  \
# 0                               NaN                       NaN
# 1                               NaN                      SDG3
# 2                               NaN                       NaN
# 3    Human Development Index (HDI)   Life expectancy at birth
# 5                              2021                      2021
# ..                              ...                       ...
# 271                             NaN                       NaN
# 272                             NaN                       NaN
# 273                             NaN                       NaN
# 274                             NaN                       NaN
# 275                             NaN                       NaN
#
#                             EYOS                     MYOS  \
# 0                            NaN                      NaN
# 1                         SDG4.3                   SDG4.4
# 2                            NaN                      NaN
# 3    Expected years of schooling  Mean years of schooling
# 5                           2021                     2021
# ..                           ...                      ...
# 271                          NaN                      NaN
# 272                          NaN                      NaN
# 273                          NaN                      NaN
# 274                          NaN                      NaN
# 275                          NaN                      NaN
#
#                                       GNIPC
# 0                                       NaN
# 1                                    SDG8.5
# 2                                       NaN
# 3    Gross national income (GNI) per capita
# 5                                      2021
# ..                                      ...
# 271                                     NaN
# 272                                     NaN
# 273                                     NaN
# 274                                     NaN
# 275                                     NaN
#
# [84 rows x 7 columns]

# %% [markdown]
# The exploration let us find that we have 84 rows with at least one missing value.
#
# * First decision, drop rows where all variable values are missing:

# %%
better_4[better_4.iloc[:,2:].isna().all(axis=1)]
# Out:
#     Hdi Rank                                            Country  HDI LEAB  \
# 0        NaN                                                NaN  NaN  NaN
# 2        NaN                                                NaN  NaN  NaN
# 6        NaN                        VERY HIGH HUMAN DEVELOPMENT  NaN  NaN
# 73       NaN                             HIGH HUMAN DEVELOPMENT  NaN  NaN
# 123      NaN                           MEDIUM HUMAN DEVELOPMENT  NaN  NaN
# ..       ...                                                ...  ...  ...
# 271      NaN                          Column 2: UNDESA (2022a).  NaN  NaN
# 272      NaN  Column 3: CEDLAS and World Bank (2022), ICF Ma...  NaN  NaN
# 273      NaN  Column 4: Barro and Lee (2018), ICF Macro Demo...  NaN  NaN
# 274      NaN  Column 5: IMF (2022), UNDESA (2022b), United N...  NaN  NaN
# 275      NaN  Column 6: Calculated based on data in columns ...  NaN  NaN
#
#     EYOS MYOS GNIPC
# 0    NaN  NaN   NaN
# 2    NaN  NaN   NaN
# 6    NaN  NaN   NaN
# 73   NaN  NaN   NaN
# 123  NaN  NaN   NaN
# ..   ...  ...   ...
# 271  NaN  NaN   NaN
# 272  NaN  NaN   NaN
# 273  NaN  NaN   NaN
# 274  NaN  NaN   NaN
# 275  NaN  NaN   NaN
#
# [62 rows x 7 columns]

# %%
better_4=better_4[~better_4.iloc[:,2:].isna().all(axis=1)]

# filtered!
better_4
# Out:
#      Hdi Rank                                            Country  \
# 1         NaN                                                NaN
# 3         NaN                                                NaN
# 4    HDI rank                                            Country
# 5         NaN                                                NaN
# 7           1                                        Switzerland
# ..        ...                                                ...
# 221       NaN                                 Sub-Saharan Africa
# 223       NaN                          Least developed countries
# 224       NaN                     Small island developing states
# 226       NaN  Organisation for Economic Co-operation and Dev...
# 228       NaN                                              World
#
#                                 HDI                      LEAB  \
# 1                               NaN                      SDG3
# 3    Human Development Index (HDI)   Life expectancy at birth
# 4                             Value                   (years)
# 5                              2021                      2021
# 7                             0.962                   83.9872
# ..                              ...                       ...
# 221                           0.547                 60.112467
# 223                            0.54                 64.215856
# 224                            0.73                 70.325547
# 226                           0.899                 78.987605
# 228                           0.732                 71.365465
#
#                             EYOS                     MYOS  \
# 1                         SDG4.3                   SDG4.4
# 3    Expected years of schooling  Mean years of schooling
# 4                        (years)                  (years)
# 5                           2021                     2021
# 7                      16.500299                 13.85966
# ..                           ...                      ...
# 221                    10.267338                 6.001639
# 223                    10.182659                  5.21532
# 224                    12.422289                  9.08964
# 226                    16.459253                12.267755
# 228                    12.780907                 8.617461
#
#                                       GNIPC
# 1                                    SDG8.5
# 3    Gross national income (GNI) per capita
# 4                              (2017 PPP $)
# 5                                      2021
# 7                               66933.00454
# ..                                      ...
# 221                             3698.868914
# 223                             2880.652487
# 224                            16782.329527
# 226                            45086.969067
# 228                            16752.082922
#
# [214 rows x 7 columns]

# %% [markdown]
# * Second decision: drop the rows with where 'Country', the ID, is missing.

# %%
better_4=better_4[~better_4.loc[:,'Country'].isna()]
better_4
# Out:
#      Hdi Rank                                            Country    HDI  \
# 4    HDI rank                                            Country  Value
# 7           1                                        Switzerland  0.962
# 8           2                                             Norway  0.961
# 9           3                                            Iceland  0.959
# 10          4                             Hong Kong, China (SAR)  0.952
# ..        ...                                                ...    ...
# 221       NaN                                 Sub-Saharan Africa  0.547
# 223       NaN                          Least developed countries   0.54
# 224       NaN                     Small island developing states   0.73
# 226       NaN  Organisation for Economic Co-operation and Dev...  0.899
# 228       NaN                                              World  0.732
#
#           LEAB       EYOS       MYOS         GNIPC
# 4      (years)    (years)    (years)  (2017 PPP $)
# 7      83.9872  16.500299   13.85966   66933.00454
# 8      83.2339    18.1852   13.00363   64660.10622
# 9      82.6782  19.163059   13.76717   55782.04981
# 10     85.4734   17.27817   12.22621    62606.8454
# ..         ...        ...        ...           ...
# 221  60.112467  10.267338   6.001639   3698.868914
# 223  64.215856  10.182659    5.21532   2880.652487
# 224  70.325547  12.422289    9.08964  16782.329527
# 226  78.987605  16.459253  12.267755  45086.969067
# 228  71.365465  12.780907   8.617461  16752.082922
#
# [211 rows x 7 columns]

# %% [markdown]
# * Third decision : Keep rows with some important values:

# %%
# detecting non-numeric cells in HDI
better_4[pd.to_numeric(better_4.HDI,'coerce').isna()]
# Out:
#      Hdi Rank                              Country    HDI     LEAB      EYOS  \
# 4    HDI rank                              Country  Value  (years)   (years)
# 202       NaN  Korea (Democratic People's Rep. of)     ..  73.2845  10.78317
# 203       NaN                               Monaco     ..  85.9463        ..
# 204       NaN                                Nauru     ..   63.617  11.69042
# 205       NaN                              Somalia     ..  55.2803        ..
#
#         MYOS         GNIPC
# 4    (years)  (2017 PPP $)
# 202       ..            ..
# 203       ..            ..
# 204       ..   17729.74084
# 205       ..    1017.96785

# %%
# then
better_4=better_4[~pd.to_numeric(better_4.HDI,'coerce').isna()]
better_4
# Out:
#     Hdi Rank                                            Country    HDI  \
# 7          1                                        Switzerland  0.962
# 8          2                                             Norway  0.961
# 9          3                                            Iceland  0.959
# 10         4                             Hong Kong, China (SAR)  0.952
# 11         5                                          Australia  0.951
# ..       ...                                                ...    ...
# 221      NaN                                 Sub-Saharan Africa  0.547
# 223      NaN                          Least developed countries   0.54
# 224      NaN                     Small island developing states   0.73
# 226      NaN  Organisation for Economic Co-operation and Dev...  0.899
# 228      NaN                                              World  0.732
#
#           LEAB       EYOS       MYOS         GNIPC
# 7      83.9872  16.500299   13.85966   66933.00454
# 8      83.2339    18.1852   13.00363   64660.10622
# 9      82.6782  19.163059   13.76717   55782.04981
# 10     85.4734   17.27817   12.22621    62606.8454
# 11     84.5265   21.05459   12.72682   49238.43335
# ..         ...        ...        ...           ...
# 221  60.112467  10.267338   6.001639   3698.868914
# 223  64.215856  10.182659    5.21532   2880.652487
# 224  70.325547  12.422289    9.08964  16782.329527
# 226  78.987605  16.459253  12.267755  45086.969067
# 228  71.365465  12.780907   8.617461  16752.082922
#
# [206 rows x 7 columns]

# %% [markdown]
# Let's explore why some rows have no ranking:

# %%
better_4[better_4.loc[:,'Hdi Rank'].isna()]
# Out:
#     Hdi Rank                                            Country    HDI  \
# 208      NaN                        Very high human development  0.896
# 209      NaN                             High human development  0.754
# 210      NaN                           Medium human development  0.636
# 211      NaN                              Low human development  0.518
# 213      NaN                               Developing countries  0.685
# 216      NaN                                        Arab States  0.708
# 217      NaN                          East Asia and the Pacific  0.749
# 218      NaN                            Europe and Central Asia  0.796
# 219      NaN                    Latin America and the Caribbean  0.754
# 220      NaN                                         South Asia  0.632
# 221      NaN                                 Sub-Saharan Africa  0.547
# 223      NaN                          Least developed countries   0.54
# 224      NaN                     Small island developing states   0.73
# 226      NaN  Organisation for Economic Co-operation and Dev...  0.899
# 228      NaN                                              World  0.732
#
#           LEAB       EYOS       MYOS         GNIPC
# 208  78.521301  16.506485  12.323006  43751.596458
# 209  74.709094  14.219287   8.327011   15167.24771
# 210  67.438318  11.944855   6.872257   6353.491965
# 211  61.310991   9.459357   4.860214   3009.120913
# 213  69.866725  12.315912   7.545938  10703.751015
# 216   70.89504  12.353535    8.02855  13500.556146
# 217   75.57965  13.816818   7.839329   15580.43686
# 218  72.856526  15.446546  10.553922  19351.837024
# 219   72.09989  14.767956     8.9977  14520.661245
# 220   67.85553  11.562208   6.710321   6481.393135
# 221  60.112467  10.267338   6.001639   3698.868914
# 223  64.215856  10.182659    5.21532   2880.652487
# 224  70.325547  12.422289    9.08964  16782.329527
# 226  78.987605  16.459253  12.267755  45086.969067
# 228  71.365465  12.780907   8.617461  16752.082922

# %% [markdown]
# Then, we can keep good ranking values:

# %%
better_4=better_4[~better_4.loc[:,'Hdi Rank'].isna()]

better_4
# Out:
#     Hdi Rank                   Country    HDI     LEAB       EYOS      MYOS  \
# 7          1               Switzerland  0.962  83.9872  16.500299  13.85966
# 8          2                    Norway  0.961  83.2339    18.1852  13.00363
# 9          3                   Iceland  0.959  82.6782  19.163059  13.76717
# 10         4    Hong Kong, China (SAR)  0.952  85.4734   17.27817  12.22621
# 11         5                 Australia  0.951  84.5265   21.05459  12.72682
# ..       ...                       ...    ...      ...        ...       ...
# 196      187                   Burundi  0.426  61.6627  10.722722  3.129267
# 197      188  Central African Republic  0.404  53.8947   8.040172     4.334
# 198      189                     Niger    0.4  61.5763   6.957112  2.116717
# 199      190                      Chad  0.394  52.5254   8.035914  2.573774
# 200      191               South Sudan  0.385  54.9752    5.54251   5.72614
#
#            GNIPC
# 7    66933.00454
# 8    64660.10622
# 9    55782.04981
# 10    62606.8454
# 11   49238.43335
# ..           ...
# 196   731.786709
# 197   966.058611
# 198  1239.866936
# 199  1364.169417
# 200      767.787
#
# [191 rows x 7 columns]

# %% [markdown]
# #### Preventive Cleaning
#
# It seems pretty clean. However, let's play safe and get rid of trailing or leading spaces :

# %%
# no trailing nor leading spaces
better_4.loc[:,'Country']=better_4.Country.str.strip()

# %% [markdown]
# Are the numeric values read as strings?

# %%
better_4.iloc[0,:].to_list()
# Out:
# [1, 'Switzerland', 0.962, 83.9872, 16.50029945, 13.85966015, 66933.00454]

# %% [markdown]
# If this does not work, the numbers are not clean:

# %%
better_4.iloc[:,2:].apply(lambda x:pd.to_numeric(x)).isnull().sum()
# Out:
# HDI      0
# LEAB     0
# EYOS     0
# MYOS     0
# GNIPC    0
# dtype: int64

# %% [markdown]
# We did not have a cell with the inappropiate characters representing numerical values, but what if:

# %%
# some messy numeric data
import numpy as np

# using vector to mimic R (columns are vectors)
var1=np.array(["1",'$3,4',"5.6","2.3",1])
var2=np.array(["1.3",'3 400',"5'6","211.333",15])
test=pd.DataFrame({'var1':var1,'var2':var2})
test

# %% [markdown]
# This code may come in handy:

# %%
badValues=[] # empty list, here we will save the wrong strings
goodStringForNumbers='^\d+\.*\d*$'

for col in test:
    currentBad=test[col][~test[col].str.contains(goodStringForNumbers,regex=True)].to_list()
    badValues.extend(currentBad)

set(badValues) # using set to see unique cases

# %% [markdown]
# We finished the cleaning. Let's reset the row indexes to finish the job:

# %%
better_4.reset_index(drop=True, inplace=True)
better_4
